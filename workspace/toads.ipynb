# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set_style("whitegrid")

# %%
cols = ["customer_id", "merchant_id", "n_toads_2014", "n_subs_2014", "merchant_id_2015","n_toads_2015", "n_subs_2015"]
toads = pd.read_csv("data/toads.csv", names=cols)

# %%
plt.figure(figsize=(20,10))
rp = sns.regplot(x="n_toads_2014", y="n_toads_2015", data=toads, x_estimator=np.mean, x_ci=99, color="#ddbbbb")
#             x_jitter=0.5, y_jitter=0.5, 
#             color="#000000", marker='.', scatter_kws={"alpha":0.5})

rp.set(xlim=[0, 30], ylim=[0, 20])
# Out:
# [(0, 20), (0, 30)]

# %%
plt.figure(figsize=(20,10))
rp = sns.regplot(x="n_subs_2014", y="n_subs_2015", data=toads, x_estimator=np.mean, x_ci=99, color="#ddbbbb")
#             x_jitter=0.5, y_jitter=0.5, 
#             color="#000000", marker='.', scatter_kws={"alpha":0.5})

rp.set(xlim=[0, 30], ylim=[0, 20])
# Out:
# [(0, 20), (0, 30)]

# %%
toads["toads_perc_2014"] = toads["n_toads_2014"] / toads["n_subs_2014"]
toads["toads_perc_2015"] = toads["n_toads_2015"] / toads["n_subs_2015"]
toads_nontrivial = toads[toads["toads_perc_2015"]>0][toads["toads_perc_2015"]<1][toads["toads_perc_2014"]>0][toads["toads_perc_2014"]<1]
# Out:
# /usr/lib/python3/dist-packages/pandas/core/frame.py:1686: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   "DataFrame index.", UserWarning)

# %%
plt.figure(figsize=(20,10))
rp = sns.regplot(x="toads_perc_2014", y="toads_perc_2015", data=toads_nontrivial,#)#, x_estimator=np.mean)
#             x_jitter=0.5, y_jitter=0.5, 
            color="#ddbbbb", marker='o', scatter_kws={"alpha":0.2, 's':300})#, fit_reg=False)
rp.set(xlim=[0, 1], ylim=[0, 1])
# Out:
# [(0, 1), (0, 1)]
